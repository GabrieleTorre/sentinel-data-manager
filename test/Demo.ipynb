# %%
from sentinel_2 import data_manager
from glob import glob

# %%
f = glob('/data/2/Sentinel2-crops/T32TNQ/*')[4]

# %%
dm = data_manager(f)

# %%
dm.descrive_veg_type_(seg_type='panoptic')
# Out:
# 0     0.979309
# 12    0.020691
# dtype: float64

# %%
dm.get_index_ts(dm.ndvi, veg_type=12, seg_type='panoptic').plot()
# Out:
# /projects/DeepLeey/agri-tech/sentinel-data-manager/test/env/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# <AxesSubplot:>
